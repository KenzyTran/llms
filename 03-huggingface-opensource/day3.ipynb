# %% [markdown]
# # Day 3 — Tokenizer của các mô hình open-source
#
# So sánh tokenizer của nhiều model HuggingFace khác nhau (Llama, Qwen, Phi, Mistral…) để thấy cách mỗi model chia nhỏ văn bản. Chạy trên Colab.
