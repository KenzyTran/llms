# %% [markdown]
# # Day 2 — HuggingFace `pipelines`
#
# High-level API của HuggingFace: chỉ vài dòng code là có ngay một mô hình open-source chạy cho các task như sentiment, summarization, translation, image generation, audio…
#
# Notebook này chạy trên Colab với T4 GPU (miễn phí). Nhớ cấu hình `HF_TOKEN` trong phần Secrets của Colab.
