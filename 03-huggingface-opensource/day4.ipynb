# %% [markdown]
# # Day 4 — `AutoModel` và `AutoTokenizer`
#
# Đi sâu vào tầng thấp hơn `pipelines`: tự tải model, tự tokenize, tự forward và tự decode. Đây là cách phải làm khi muốn custom nhiều hơn (4-bit quantization, generation config, streaming…). Chạy trên Colab T4.
