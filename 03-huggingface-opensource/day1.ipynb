# %% [markdown]
# # Week 3 — Day 1: Làm quen với Google Colab
#
# Tuần này mình chuyển sang chạy các mô hình **open-source HuggingFace** — chúng cần GPU nên mình dùng [Google Colab](https://colab.research.google.com/). Free tier là đủ cho phần lớn notebook; mình cá nhân dùng Colab Pro+ cho các bài nặng.
#
# Từ đây trở đi các notebook Week 3 chủ yếu là link dẫn tới Colab tương ứng.
