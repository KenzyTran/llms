# %% [markdown]
# # Bài tập cuối Week 2
#
# Nâng cấp tool kỹ thuật từ Week 1 thành một prototype đầy đủ: Gradio UI, streaming, system prompt chuyên môn, có thể **đổi model động** giữa OpenAI / Claude / Gemini / Ollama, và (bonus) dùng tool use.
